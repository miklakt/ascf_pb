# %%
import matplotlib.pyplot as plt
import ascf_pb

# %%
chi0= 0.5
sigma0 = 0.05
N0=10000

H0 = ascf_pb.H(sigma0, chi0, N0)

z0 = range(int(H0)+2)

phi = ascf_pb.phi(chi = chi0, sigma=sigma0, N=N0)(z0)

# %%
plt.plot(z0,phi)

# %% [markdown]
# # Volume fraction
#
# lsdfpk osjgf'psiogfj oipore
#
# $$
# \phi(0)=\ln(1-\phi)
# $$
